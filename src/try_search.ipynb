# %%
#generate title only csv file
import pandas as pd
#pd.read_csv("../data/mixed-news/articles1-title_only.csv",encoding='ISO-8859-1')
# full = pd.read_csv("../data/mixed-news/articles1.csv")
# title = full.iloc[:1000,9]
# title.to_csv("../data/mixed-news/articles-title_only.csv",header="True")

# %%
from reader import Reader
from search import Search

# %%
read = Reader()
seac = Search()
# Out:
# [nltk_data] Downloading package punkt to /home/wenhao/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/wenhao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
news_list = read.read_csv_file("../data/mixed-news/articles-title_only.csv")

# %%
news_list[0]
# Out:
# 'When the Boy Scouts of America announced Monday that transgender boys would be welcome to camp, hike and earn merit badges alongside their peers, the move brought praise from critics of the organization who for years have called for more inclusive membership rules. But the decision, which came with little warning and reversed a more than   stance of determining gender based on birth certificates, further alienated many religious conservatives who were longtime advocates of the program. “Now we see once again that the Boy Scouts really is committed to a   culture war that evangelical Christians and many other Americans just can’t accept,” said Russell Moore, the president of the Ethics  Religious Liberty Commission, the public policy arm of the Southern Baptist Convention. Mr. Moore, a former scout, said Southern Baptist churches and others had been dismayed by Boy Scout policies for several years, as the Scouts moved first to allow openly gay youth members, and then openly gay adult
# ...

# %%
entity = read.parse_news(news_list[0:1])
entity
# Out:
# [('Boy', 'O'),
#  ('Scouts', 'O'),
#  ('America', 'LOCATION'),
#  ('announced', 'O'),
#  ('Monday', 'O'),
#  ('transgender', 'O'),
#  ('boys', 'O'),
#  ('would', 'O'),
#  ('welcome', 'O'),
#  ('camp', 'O'),
#  (',', 'O'),
#  ('hike', 'O'),
#  ('earn', 'O'),
#  ('merit', 'O'),
#  ('badges', 'O'),
#  ('alongside', 'O'),
#  ('peers', 'O'),
#  (',', 'O'),
#  ('move', 'O'),
#  ('brought', 'O'),
#  ('praise', 'O'),
#  ('critics', 'O'),
#  ('organization', 'O'),
#  ('years', 'O'),
#  ('called', 'O'),
#  ('inclusive', 'O'),
#  ('membership', 'O'),
#  ('rules', 'O'),
#  ('.', 'O'),
#  ('decision', 'O'),
#  (',', 'O'),
#  ('came', 'O'),
#  ('little', 'O'),
#  ('warning', 'O'),
#  ('reversed', 'O'),
#  ('stance', 'O'),
#  ('determining', 'O'),
#  ('gender', 'O'),
#  ('based', 'O'),
#  ('birth', 'O'),
#  ('certificates', 'O'),
#  (',', 'O'),
#  ('alienated', 'O'),
#  ('many', 'O'),
#  ('religious', 'O'),
#  ('conservatives', 'O'),
#  ('longtime', 'O'),
#  ('advocates', 'O'),
# ...

# %%
new,exist = seac.query(entity)
#why this failed

# %%
len(exist)

# %%
exist
